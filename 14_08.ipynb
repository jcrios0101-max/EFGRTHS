# %% [markdown]
# <a href="https://colab.research.google.com/github/jcrios0101-max/EFGRTHS/blob/main/14_08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 1

idade = int (input("Digite sua idade: "))

if idade >= 18:
 print (f"com {idade} anos, você ja pode dirigir")

else:
  print (f"com {idade} anos, você ainda não pode dirigir")
# Out:
# Digite sua idade: 17
# com 17 anos, você ainda não pode dirigir

# %%
#Exercício 2

numero = int (input( "Digite um numero: "))

if numero % 2 == 0:

  print (f"o numero {numero} é par")

else:

   print (f"o numero {numero} é impar")
# Out:
# Digite um numero: 8
# o numero 8 é par

# %%
#Exercício 3

n1 = int(input("Digite o primeiro número: "))
n2 = int(input("Digite o segundo número: "))

if n1>n2:
  print (f"o número {n1} é maior que o {n2}")

elif n1<n2:
  print (f"o número {n2} é maior que o {n1}")

else:
  print (f"os dois números são iguais")
# Out:
# Digite o primeiro número: 6
# Digite o segundo número: 7
# o número 7 é maior que o 6

# %%
#Exercício 4

nota1 = float (input("digite a nota do bimestre 1: "))
nota2 = float (input("digite a nota do bimestre 2: "))
nota3 = float (input("digite a nota do bimestre 3: "))
nota4 = float (input("digite a nota do bimestre 4: "))

media = ((nota1+nota2+nota3+nota4)/4)

if media < 5 :

  print (f"media: {media} aluno reprovado")

elif media >= 5 and media < 7 :

  print (f"media: {media} aluno de recuperação")

else:

  print (f"media: {media} aluno aprovado")
# Out:
# digite a nota do bimestre 1: 7
# digite a nota do bimestre 2: 8
# digite a nota do bimestre 3: 6
# digite a nota do bimestre 4: 9
# media: 7.5 aluno aprovado

# %%
#Exercício 5

v = float (input("digite o valor da compra: "))
d = v*0.10
vf = v-(d)

if v>= 100:
  print (f"o valor do desconto é de {d} reais, e o valor final da compra foi de {vf} reais")

else:
  print (f"o valor é menor do que 100, portanto continua em seu valor original de {v} reais")
# Out:
# digite o valor da compra: 79
# o valor é menor do que 100, portanto continua em seu valor original de 79.0 reais

# %%
#Exercício 6

n = int (input("Digite um número: "))

if n>0:
  print (f"o número é positivo")

elif n<0:
  print (f"o número é negativo")

else:
  print (f"o número é zero")
# Out:
# Digite um número: 0
# o número é zero

# %%
#Exercício 7

idade = int (input( "Digite uma idade: "))

if idade < 12 :
 print (f"você é uma criança")

elif idade < 18 :
  print (f"você é um adolescente")

elif idade < 60 :
  print (f"você é um adulto")

else:
  print (f"você é um idoso")
# Out:
# Digite uma idade: 15
# você é um adolescente

# %%
#Exercício 8

nota1 = float (input("digite a nota do bimestre 1: "))
nota2 = float (input("digite a nota do bimestre 2: "))

m = (nota1+nota2)/2

if m<7:
  print (f"aluno reprovado")

else:
  print(f"aluno aprovado")
# Out:
# digite a nota do bimestre 1: 7
# digite a nota do bimestre 2: 7
# aluno aprovado

# %%
#Exercício 9

u = str (input("digite seu nome de usuário: "))
s = int (input("digite sua senha: "))

if u == "admin" and s == 1234:
  print (f"Login realizado com sucesso")

else:
  print (f"Usuário ou senha incorretos")
# Out:
# digite seu nome de usuário: admin
# digite sua senha: 1234
# Login realizado com sucesso

# %%
#Exercício 10

a = float (input("Digite sua altura: "))
p = float (input("Digte seu peso: "))
IMC = (p/(a*a))

if IMC<18.5:
  print(f"seu IMC é {IMC}, esta abaixo do peso")

elif IMC<=24.9:
  print(f"seu IMC é {IMC}, esta com o peso normal")

elif IMC<29.9:
  print(f"seu IMC é {IMC}, esta em sobrepeso")

else:
  print(f"seu IMC é {IMC}, esta em obesidade")
# Out:
# Digite sua altura: 1.67
# Digte seu peso: 65
# seu IMC é 23.306680053067517, esta com o peso normal
