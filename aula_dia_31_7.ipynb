# %% [markdown]
# <a href="https://colab.research.google.com/github/jcrios0101-max/EFGRTHS/blob/main/aula_dia_31_7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Exercício 1

nome = str(input("digite seu nome: "))
idade = int(input("digite sua idade: "))
cidade = str(input("digite sua cidade: "))

print (f"olá {nome}, vc tem {idade} anos, e mora na cidade de {cidade}")
# Out:
# digite seu nome: Rios
# digite sua idade: 15
# digite sua cidade: Ribeirão Pires
# olá Rios, vc tem 15 anos, e mora na cidade de Ribeirão Pires

# %%
#Exercício 2

numero = int(input("digite um número: "))

print (f"o número é {numero}, seu antecessor é {numero-1}, e seu sucessor é {numero+1}")
# Out:
# digite um número: 67
# o número é 67, seu antecessor é 66, e seu sucessor é 68

# %%
#Exercício 3

n1 = int(input("digite o primeiro numero: "))
n2 = int(input("digite o segundo numero: "))

print (f"Soma: {n1+n2}, subtração: {n1-n2}, multiplicação: {n1*n2}, divisão: {n1/n2}")
# Out:
# digite o primeiro numero: 2
# digite o segundo numero: 2
# Soma: 4, subtração: 0, multiplicação: 4, divisão: 1.0

# %%
#Exercício 4
#entrada

nota1 = float (input("digite a nota do bimestre 1: "))
nota2 = float (input("digite a nota do bimestre 2: "))
nota3 = float (input("digite a nota do bimestre 3: "))
nota4 = float (input("digite a nota do bimestre 4: "))

#Procesamento/saída

media = ((nota1+nota2+nota3+nota4)/4)

if media < 5 :

  print (f"media: {media} aluno reprovado")

elif media >= 5 and media < 7 :

  print (f"media: {media} aluno de recuperação")

else:

  print (f"media: {media} aluno aprovado")
# Out:
# digite a nota do bimestre 1: 7
# digite a nota do bimestre 2: 7
# digite a nota do bimestre 3: 7
# digite a nota do bimestre 4: 7
# media: 7.0 aluno aprovado

# %%
#Exercício 5

c = int(input("digite uma temperatura em celcius: "))

print (f"a temperatura {c} graus celcius, em fahrenheit é igual a {c*1.8+32}")
# Out:
# digite uma temperatura em celcius: 20
# a temperatura 20 graus celcius, em fahrenheit é igual a 68.0

# %%
#Exercício 6

h = int(input("digite a altura: "))
b = int(input("digite a base: "))

print (f"a área do retângulo é igual a {b*h}")
# Out:
# digite a altura: 5
# digite a base: 2
# a área do retângulo é igual a 10

# %%
#Exercicío 7

#Entrada

numero = int (input( "Digite um numero: "))

# Processamento / Saída

if numero % 2 == 0:

  print (f"o numero {numero} é par")

else:

   print (f"o numero {numero} é impar")
# Out:
# Digite um numero: 8
# o numero 8 é par

# %%
#Exercício 8

n1 = float(input("Digite o primeiro número: "))
n2 = float(input("Digite o segundo número: "))
n3 = float(input("Digite o terceiro número: "))

if n1 > n2 and n1 > n3:
    maior = n1
elif n2 > n1 and n2 > n3:
    maior = n2
else:
    maior = n3

print("O maior número é:", maior)
# Out:
# Digite o primeiro número: 99
# Digite o segundo número: 9
# Digite o terceiro número: 9
# O maior número é: 99.0

# %%
#9 Exercício

numero = int (input("digite um numero: "))

if 1 <= numero <= 10:
  print(f"tabuada do {numero}:")
  for i in range(1, 11):
    print(f"{numero} x {i} = {numero * i}")
# Out:
# digite um numero: 9
# tabuada do 9:
# 9 x 1 = 9
# 9 x 2 = 18
# 9 x 3 = 27
# 9 x 4 = 36
# 9 x 5 = 45
# 9 x 6 = 54
# 9 x 7 = 63
# 9 x 8 = 72
# 9 x 9 = 81
# 9 x 10 = 90

# %%
#Exercício

opcao = 0
a = 0
b = 0

while opcao != 5:

 opcao = int(input("digite uma opção de 1 a 4, ou 5 para sair: "))

 if opcao == 1:

  a = int(input("digite um numero: "))
  b = int(input("digite um numero: "))

  print(f"total da soma igual {a + b} ")


 elif opcao ==2:

  a = int(input("digite um numero: "))
  b = int(input("digite um numero: "))

  print(f"total da subtração igual {a - b} ")

 elif opcao ==3:

  a = int(input("digite um numero: "))
  b = int(input("digite um numero: "))

  print(f"total da multiplicação igual {a * b} ")

 elif opcao ==4:

  a = int(input("digite um numero: "))
  b = int(input("digite um numero: "))

  print(f"total da divisão igual {a / b} ")

else:
  print("até mais!")
# Out:
# digite uma opção de 1 a 4, ou 5 para sair: 3
# digite um numero: 4
# digite um numero: 3
# total da multiplicação igual 12
# digite uma opção de 1 a 4, ou 5 para sair: 5
# até mais!
